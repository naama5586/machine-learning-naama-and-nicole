# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\LAB-ORENMUZ\\Desktop\\NaamaNicole\\calc_by_distance_NEW3_Spatial.csv')
data.shape

# %%
data_main = pd.read_csv('C:\\Users\\LAB-ORENMUZ\\Desktop\\NaamaNicole\\calc_participant_participation_order.csv')
data_main = data_main[data_main['Condition'] == 'Allocentric']

# %%
col_list = data_main.isnull().sum()#.tolist()

# %%
for col in col_list:
    print(col)
# Out:
# 0
# 0
# 0
# 0
# 50
# 65
# 65
# 65
# 50
# 50
# 50
# 65
# 65
# 50
# 50
# 50
# 50
# 50
# 50
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 55
# 50
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 131
# 131
# 131
# 131
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 83
# 83
# 83
# 83
# 128
# 128
# 128
# 128
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# ...

# %%
df = data_main.dropna(thresh = len(data_main) - 100, axis = 1)

# %%
df.to_csv("C:\\Users\\USER\\Desktop\\לימודים\\שנה ד\\machine_learning_project\\Spatial_after_droping_missing_values_al&eg.csv", index=False)
